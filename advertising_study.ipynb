# %%
import pandas as pd

# %%
data=pd.read_csv('Advertising.csv', index_col=0)
#display first 5 rows
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
# display lat 5 rows
data.tail()
# Out:
#         TV  radio  newspaper  sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (200, 4)

# %%
import seaborn as sns # this package is used for statistical methods
 #alternate method to import this package: allows all plots to appear in the notebook
# %matplotlib inline

# %%
# visualise the relationship between the features and the response
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars='sales',size=7,aspect=0.6,kind='reg') #regression st. line
